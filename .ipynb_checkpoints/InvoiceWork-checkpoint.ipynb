# %%
import csv
import pandas as pd
import numpy as np
import math
import glob
import datetime




##----Here we first clean data and add Porper Date format to each day of the week

# df = pd.read_csv("sunday.csv")
# df.dropna(subset=['ROUTE'], axis = 'rows', how ='all', inplace = True) 
# df.fillna(0,inplace = True)
# df.drop(["VANS", "Unnamed: 16"],axis = 1,inplace = True, errors = 'ignore')
# df["date"] = "Sun 26 April 2020"
# df.to_csv("sunday.csv", index=False)
# df


# df = pd.read_csv("monday.csv")
# df.dropna(subset=['ROUTE'], axis = 'rows', how ='all', inplace = True) 
# df.fillna(0,inplace = True)
# #df.drop(["VANS", "Unnamed: 16","WEEK"],axis = 1,inplace = True, errors = 'ignore')
# df["date"] = "Mon 27 April 2020"
# df.to_csv("monday.csv", index=False)
# df

# df = pd.read_csv("tuesday.csv")
# df.dropna(subset=['IN'], axis = 'rows', how ='all', inplace = True) 
# df.fillna(0,inplace = True)
# df.drop(["VANS","WEEK"],axis = 1,inplace = True, errors = 'ignore')
# df["date"] = "Tue 28 April 2020"
# df.to_csv("tuesday.csv", index=False)
# df

# wed = pd.read_csv("wednesday.csv")
# wed.dropna(subset=['IN'], axis = 'rows', how ='all', inplace = True) 
# wed.fillna(0,inplace = True)
# wed.drop(["VANS","WEEK"],axis = 1,inplace = True, errors = 'ignore')
# wed["date"] = "Wed 29 April 2020"
# wed.to_csv("wednesday.csv", index=False)





# df = pd.read_csv("thursday.csv")
# df.dropna(subset=['IN'], axis = 'rows', how ='all', inplace = True) 
# df.fillna(0,inplace = True)
# df.drop(["VANS","WEEK"],axis = 1,inplace = True, errors = 'ignore')
# df["date"] = "Thu 30 April 2020"
# df.to_csv("thursday.csv", index=False)
# df


# df = pd.read_csv("friday.csv")
# df.dropna(subset=['ROUTE'], axis = 'rows', how ='all', inplace = True) 
# df.fillna(0,inplace = True)
# df.drop(["VANS","WEEK"],axis = 1,inplace = True, errors = 'ignore')
# df["date"] = "Fri 1 May 2020"
# df.to_csv("friday.csv", index=False)
# df


# df = pd.read_csv("saturday.csv")
# df.dropna(subset=['ROUTE'], axis = 'rows', how ='all', inplace = True) 
# df.fillna(0,inplace = True)
# df.drop(["VANS","WEEK"],axis = 1,inplace = True, errors = 'ignore')
# df["date"] = "Sat 2 May 2020"
# df.to_csv("saturday.csv", index=False)
# df


#here we combine our clean data

sun = pd.read_csv("sunday.csv")
mon = pd.read_csv("monday.csv")
tue = pd.read_csv("tuesday.csv")
wed = pd.read_csv("wednesday.csv")
thu = pd.read_csv("thursday.csv")
fri = pd.read_csv("friday.csv")
sat = pd.read_csv("saturday.csv")

myDatesArray = pd.concat([sun,mon,tue,wed,thu,fri,sat], axis=0)
myDatesArray = myDatesArray.reset_index(drop=True)
myDatesArray
#myDatesArray.dtypes
# Out:
#                       NAME   IN ROUTE LOG IN LOG OUT  TORH  MILEAGE  PARCEL  \
# 0         ADRIAN MACIASZEK  1.0  A133  10:15   16:25  6:10    124.0   171.0
# 1         ADRIAN NAGLEWICZ  1.0  A141  10:15   18:22  8:07    163.0   182.0
# 2           BLAZEJ KOSTERA  1.0  A138  10:15   18:02  7:47    157.0   221.0
# 3             CARLOS LOPEZ  1.0  A142  10:15   18:11  7:56    164.0   197.0
# 4            DANIEL PETROV  1.0  A140  10:15   18:42  8:27    164.0   191.0
# ..                     ...  ...   ...    ...     ...   ...      ...     ...
# 121        VESELIN VASILEV  1.0  A165  10:15   16:46  6:31    103.0     0.0
# 122  WIKTOR ALEKSANDROWICZ  1.0  A158  10:15   17:13  6:58    133.0     0.0
# 123          ZHELYO ZHELEV  1.0  A163  10:15   17:53  7:38     83.0     0.0
# 124          SABRI SABRIEV  1.0  A160  10:15   15:10  4:55     78.0     0.0
# 125           NINA PAVLOVA  1.0  A164  10:15   13:55  3:40     80.0     0.0
#
#      LWP  LVP  CRT   RL     SUP FUEL SUPPORT               date
# 0    0.0  0.0  0.0  0.0  18.00    0       0  Sun 26 April 2020
# 1    0.0  0.0  0.0  0.0  18.00    0       0  Sun 26 April 2020
# 2    0.0  0.0  0.0  0.0  18.00    0       0  Sun 26 April 2020
# 3    0.0  0.0  0.0  0.0  18.00    0       0  Sun 26 April 2020
# 4    0.0  0.0  0.0  0.0  18.00    0       0  Sun 26 April 2020
# ..   ...  ...  ...  ...     ...  ...     ...                ...
# 121  0.0  0.0  0.0  0.0  18.00    0       0     Sat 2 May 2020
# 122  0.0  0.0  0.0  0.0  18.00    0       0     Sat 2 May 2020
# 123  0.0  0.0  0.0  0.0  18.00    0       0     Sat 2 May 2020
# 124  0.0  0.0  0.0  0.0  18.00    0       0     Sat 2 May 2020
# 125  0.0  0.0  0.0  0.0  18.00    0       0     Sat 2 May 2020
#
# [126 rows x 16 columns]

# %%
from collections import defaultdict
from collections import Counter
import collections, functools, operator 

myOneWeekArray = []
weekBeforeSunday = "Sun 26 April 2020"
mostRecentSunday = "Sun 3 May 2020"




for row in myDatesArray.itertuples(index=True, name='Pandas'):
    invoiceObject = {}
    #print(getattr(row, "date"))
    if getattr(row, "NAME") == getattr(row, "NAME"):
        if weekBeforeSunday < getattr(row, "date") < mostRecentSunday:
            if len(myOneWeekArray) > 0:
                for element in myOneWeekArray[0]:
                    if element == 'LVP':
                        myOneWeekArray[0][element] = myOneWeekArray[0][element] + getattr(row, "LVP")
                        if element == 'LWP':
                            myOneWeekArray[0][element] = myOneWeekArray[0][element] + getattr(row, "LWP")
                            if element == 'CRT':
                                myOneWeekArray[0][element] = myOneWeekArray[0][element] + getattr(row, "CRT")
        else:
            invoiceObject['NAME'] = getattr(row, "NAME")
            invoiceObject['ROUTE'] = getattr(row, "ROUTE")
            invoiceObject['Support'] = getattr(row, "SUP")
            invoiceObject['Deductions'] = getattr(row, "SUPPORT")
            invoiceObject['Fuel'] = getattr(row, "FUEL")
            myOneWeekArray.append(invoiceObject)
                        
#print(myOneWeekArray)
#type(myOneWeekArray)
                

# tempSup = defaultdict(list)
# for d in myOneWeekArray:
#     tempSup[d['NAME']].append(d['Support'])
#     supp = [{'NAME': k, 'Support': v} for k, v in tempSup.items()] 

# totalSup = sum(item['count'] for item in supp)


# print(supp)

# result = dict(functools.reduce(operator.add, 
#          map(collections.Counter, supp))) 
  
# print("resultant dictionary : ", str(result)) 
  

    #sumSup = sum(tempSup[c] for c in tempSup)


    #count all routes
    
tempRoute = defaultdict(list)
for d in myOneWeekArray:
    tempRoute[d['NAME']].append(d['ROUTE'])
    tempRoute[d['NAME']].append(d['Support'])
    #routes = [{'NAME': k, 'ROUTE': v, 'support': d['Support'], 'deductions': d['Deductions']} for k, v in tempRoute.items()] 

#totalRoutes = sum(item['count'] for item in routes)

print(tempRoute)



#Here i want to make a list for each driver and the different routes they have had

tempvar = defaultdict(list)
tempVar = defaultdict(list)
payCheck = defaultdict(list)
for d in routes:
    #print(type(d['ROUTE']))
    for item in d['ROUTE']:
        if item == 'MFN':
            #print(item)
            tempVar[d['NAME']].append(item)
        elif item == 'Transportation':
                #myMFN.append(item)
            tempVar[d['NAME']].append(item)
        elif item == 'Missort':
                #myMFN.append(item)
            tempVar[d['NAME']].append(item)  
        elif item == 'Classroom Training':
            #print(item)
            tempVar[d['NAME']].append(item)
        elif item == 'Ride Along':
            #print(item)
            tempVar[d['NAME']].append(item)
#         else:
#             tempVar[d['NAME']].append(item)
            
            
#print(tempVar)   
#print(invVar)
#totalMFN = sum(item['count'] for item in myMFN)
#print(totalMFN) 
#print("Total MFN Routes for WEEK 18 is:", totalMFN)   #6


#print("Total Transportation Routes for WEEK 18 is:", totalTranssp)   #1
# Out:
# defaultdict(<class 'list'>, {'ADRIAN MACIASZEK': ['A133', '18.00', 'A176', '18.00'], 'ADRIAN NAGLEWICZ': ['A141', '18.00'], 'BLAZEJ KOSTERA': ['A138', '18.00', 'Transportation', '18.00', 'A176', '18.00', 'A189', '18.00', 'A196', '53.00'], 'CARLOS LOPEZ': ['A142', '18.00', 'A180', '18.00', 'A164', '18.00', 'A187', '18.00', 'A155', '18.00'], 'DANIEL PETROV': ['A140', '18.00', 'A170', '18.00', 'A176', '18.00', 'A185', '18.00'], 'DIMITAR PETKOV': ['A134', '18.00', 'Ride Along', '38.00', 'A179', '18.00', 'A190', '18.00', 'A159', '18.00'], 'EDWARD LOCK': ['A136', '18.00', 'A174', '18.00', 'A169', '18.00', 'A183', '18.00'], 'KRZYSZTOF WIECZYNSKI': ['A143', '18.00', 'A178', '18.00', 'A189', '18.00', 'A200', '38.00', 'A168', '18.00'], 'PAVLIN TODOROV': ['A139', '18.00', 'A177', '18.00', 'A174', '18.00', 'A186', '18.00', 'A157', '18.00'], 'STOYAN TENEV': ['BULK', '18.00', 'A171', '18.00', 'A193', '18.00', 'A187', '18.00', 'A197', '18.00', 'A162', '18.00'], 'SZYMON KAPINOS': ['A131', '18.00', 'A178', '18.00', 'A185', '18.00', 'A195', '18.00'], 'VESELIN VASILEV': ['A137', '18.00', 'A173', '18.00', 'A168', '18.00', 'MFN', '80.00', 'A178', '18.00', 'A165', '18.00'], 'ZHELYO ZHELEV': ['A135', '18.00', 'Classroom Training', '18.00', 'A170', '18.00', 'A180', '18.00', 'A163', '18.00'], 'PIOTR SLODEK': ['MFN', '80.00', 'MFN', '80.00'], 'ARKADIUSZ STANKEWICZ': ['A132', '18.00', 'MFN', '80.00'], 'ARTUR KOSCIEN': ['MFN', '80.00', 'Transportation', '18.00', 'A175', '18.00', 'A181', '18.00', 'A202', '18.00'], 'GALIN PETKOV': ['A179', '18.00', 'A179', '18.00'], 'GREGORY STREETE': ['A171', '18.00', 'A177', '18.00', 'A190', '18.00'], 'JAN WADOWSKI': ['A182', '18.00', 'A198', '53.00', 'A153', '9.00'], 'JAROSLAW ADAMIEC': ['Sweeper', '18.00', 'MFN', '80.00', 'A179', '18.00', 'A189', '9.00'], 'PAWEL CHMILEWSKI': ['Missort', '18.00', 'A172', '18.00', 'A183', '18.00', 'A195', '18.00', 'A188', '18.00'], 'PHLIP EDMONDSON': ['A181', '18.00', 'A177', '18.00', 'A188', '18.00', 'A197', '18.00', 'A191', '18.00'], 'DIMITAR VALEV': ['A166', '18.00', 'A182', '18.00', 'A188', '18.00', 'A176', '18.00', 'Classroom Training', '18.00'], 'GALIN PETKOV\n': ['A173', '18.00'], 'ILIYAN STOYANOV': ['A163', '18.00', 'A184', '18.00', 'A194', '18.00', 'A184', '18.00', 'A167', '18.00'], 'NORBERT LINDMANN': ['A180', '18.00', 'A192', '18.00', 'A196', '18.00', 'A189', '9.00', 'A153', '9.00'], 'RYAN CADDICK': ['A167', '18.00', 'A187', '18.00', 'A191', '18.00', 'A192', '18.00', 'Ride Along', '18.00'], 'WIKTOR ALEKSANDROWICZ': ['A175', '18.00', 'A186', '18.00', 'A192', '18.00', 'A201', '18.00', 'A158', '18.00'], 'SIMEON DIMITROV': ['A178', '18.00', 'A194', '18.00', 'A166', '18.00'], 'WOJCIECH WISNIEWSKI': ['A190', '18.00', 'A193', '18.00', 'A199', '18.00'], 'DYLAN PAUL ROBERTS': ['A182', '18.00', 'Sweeper', '18.00'], 'IVAYLO STOYKOV': ['A193', '18.00'], 'PAWEL PLONKA': ['A161', '18.00'], 'SABRI SABRIEV': ['A160', '18.00'], 'NINA PAVLOVA': ['A164', '18.00']})

# %%
invArray
# Out:
# {'NAME': 'NINA PAVLOVA', 'ROUTES': ['A164']}

# %%
from collections import defaultdict
from collections import Counter
myOneWeekArray = []
weekBeforeSunday = "Sun 26 April 2020"
mostRecentSunday = "Sun 3 May 2020"

for row in myDatesArray.itertuples(index=True, name='Pandas'):
    invoiceObject = {}
    #print(getattr(row, "date"))
    if getattr(row, "NAME") == getattr(row, "NAME"):
        if weekBeforeSunday < getattr(row, "date") < mostRecentSunday:
            if len(myOneWeekArray) > 0:
                for element in myOneWeekArray[0]:
                    if element == 'LVP':
                        myOneWeekArray[0][element] = myOneWeekArray[0][element] + getattr(row, "LVP")
                        if element == 'LWP':
                            myOneWeekArray[0][element] = myOneWeekArray[0][element] + getattr(row, "LWP")
                            if element == 'CRT':
                                myOneWeekArray[0][element] = myOneWeekArray[0][element] + getattr(row, "CRT")
                            #print(myOneWeekArray[0][element])
        else:
            invoiceObject['NAME'] = getattr(row, "NAME")
            invoiceObject['ROUTE'] = getattr(row, "ROUTE")
            #invoiceObject['LWP'] = getattr(row, "LWP")
            #invoiceObject['CRT'] = getattr(row, "CRT")
            #invoiceObject['LVP'] = getattr(row, "LVP")
            invoiceObject['Deductions'] = getattr(row, "SUP")
            invoiceObject['Fuel'] = getattr(row, "FUEL")
            myOneWeekArray.append(invoiceObject)
                        
#print(myOneWeekArray)
#type(myOneWeekArray)
                

    #count all routes
    
tempRoute = defaultdict(list)
for d in myOneWeekArray:
    tempRoute[d['NAME']].append(d['ROUTE'])
routes = [{'NAME': k, 'ROUTE': v, 'count': len(v)} for k, v in tempRoute.items()] 

totalRoutes = sum(item['count'] for item in routes)


#print(routes)
#print("Total routes for WEEK 18 is:", totalRoutes)   #126


        #here we will serch for the different route types
# Route types drop down menu:

# Full Standart Van Route
# Full Large Van Route 
# Transportation Route -done
# MFN Route - done
# Missort Route - done
# Classroom Training 
# Ride Along
# Sweeper

 
#res = None
#tempRoutes = defaultdict(list)



#Transportation
tempvar = defaultdict(list)
for d in routes:
    #print(type(d['ROUTE']))
    for item in d['ROUTE']:
        if item == 'Transportation':
            #print(item)
            tempvar[d['NAME']].append(item)
            myvar = [{'NAME': k, 'routeType': v, 'count': len(v)} for k, v in tempvar.items()]
#print(myvar)       

totalTranssp = sum(item['count'] for item in myvar)
#print(totalTranssp) 
print("Total Transportation Routes for WEEK 18 is:", totalTranssp)   #1




#Missort
tempMissort = defaultdict(list)
for d in routes:
    #print(type(d['ROUTE']))
    for item in d['ROUTE']:
        if item == 'Missort':
            #print(item)
            tempMissort[d['NAME']].append(item)
            myMissort = [{'NAME': k, 'routeType': v, 'count': len(v)} for k, v in tempMissort.items()]

print(type(myMissort))       

totalMissort = sum(item['count'] for item in myMissort)
#print(totalMissort) 
print("Total Missort Routes for WEEK 18 is:", totalMissort)   #1



#MFN
tempMFN = defaultdict(list)
for d in routes:
    #print(type(d['ROUTE']))
    for item in d['ROUTE']:
        if item == 'MFN':
            #print(item)
            tempMFN[d['NAME']].append(item)
            myMFN = [{'NAME': k, 'routeType': v, 'count': len(v)} for k, v in tempMFN.items()]     

totalMFN = sum(item['count'] for item in myMFN)
#print(totalMFN) 
print("Total MFN Routes for WEEK 18 is:", totalMFN)   #6


#Classroom Training 
tempCT = defaultdict(list)
for d in routes:
    #print(type(d['ROUTE']))
    for item in d['ROUTE']:
        if item == 'Transportation':
            #print(item)
            tempCT[d['NAME']].append(item)
            myCT = [{'NAME': k, 'routeType': v, 'count': len(v)} for k, v in tempCT.items()]
#print(myCT)       

totalCT = sum(item['count'] for item in myCT) 
#print(totalCT) 
print("Total Classroom Training for WEEK 18 is:", totalCT)   #1



#Ride Along
tempRA = defaultdict(list)
for d in routes:
    #print(type(d['ROUTE']))
    for item in d['ROUTE']:
        if item == 'Ride Along':
            #print(item)
            tempRA[d['NAME']].append(item)
            myRA = [{'NAME': k, 'routeType': v, 'count': len(v)} for k, v in tempRA.items()]
#print(myRA)       

totalRA = sum(item['count'] for item in myRA)
#print(totalRA) 
print("Total Ride Along for WEEK 18 is:", totalCT)   #1




#Sweeper
tempSW = defaultdict(list)
for d in routes:
    #print(type(d['ROUTE']))
    for item in d['ROUTE']:
        if item == 'Sweeper':
            #print(item)
            tempSW[d['NAME']].append(item)
            mySW = [{'NAME': k, 'routeType': v, 'count': len(v)} for k, v in tempSW.items()]
#print(mySW)       

totalSW = sum(item['count'] for item in mySW)
#print(totalSW) 
print("Total Ride Along for WEEK 18 is:", totalSW)   #2




                    #count all LVP

# k = 1
# templvp = defaultdict(list)
# for d in myoneweekarray:
#     if d['lvp'] == k:
#         templvp[d['name']].append(d['lvp'])
#         mylvp = [{'name': k, 'lvp': v, 'count': v.count(1)} for k, v in templvp.items()]
        
# totallvp = sum(item['count'] for item in mylvp)
# print("total lvp for week 18 is:", totallvp)   #13

# #mylvp
# #totallvp



    #count all LWP
    
# K = 1
# tempLWP = defaultdict(list)
# for d in myOneWeekArray:
#     myLWP = {}
#     if d['LWP'] == K:
#         tempLVP[d['NAME']].append(d['LWP'])
#         myLVP = [{'NAME': k, 'LWP': v, 'count': v.count(1)} for k, v in tempLWP.items()]
        
#totalLWP = sum(item['count'] for item in myLWP)
#print("Total LWP for WEEK 18 is:", totalLWP)   #13
# Out:
# Total Transportation Routes for WEEK 18 is: 2
# <class 'list'>
# Total Missort Routes for WEEK 18 is: 1
# Total MFN Routes for WEEK 18 is: 6
# Total Classroom Training for WEEK 18 is: 2
# Total Ride Along for WEEK 18 is: 2
# Total Ride Along for WEEK 18 is: 2

# %%
mylvp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-230-31da82310ab1> in <module>
# ----> 1 mylvp
#
# NameError: name 'mylvp' is not defined

# %%
    
    #count all CRT
    
#This won't work here because i have lft drivers who has "ROUTE" or "IN",
#but CRT and RT are not in the csv files 
# tempCRT = defaultdict(list)
# for d in myOneWeekArray:
#     tempCRT[d['NAME']].append(d['CRT'])
#     myCRT = [{'NAME': k, 'CRT': v, 'count': v.count(1)} for k, v in tempCRT.items()]

# totalCRT = sum(item['count'] for item in myCRT)
# totalCRT
        
#totalCRT = sum(item['count'] for item in myCRT)
#print("Total CRT for WEEK 18 is:", totalCRT)   #13
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-141b3ea3f03f> in <module>
# ----> 1 k
#
# NameError: name 'k' is not defined

# %%
#(datetime.datetime.strptime(str(myDatesArray['date']), '%a %b %d %Y'))
myDatesArray[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 9
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-8141116b617f> in <module>
#       1 #(datetime.datetime.strptime(str(myDatesArray['date']), '%a %b %d %Y'))
# ----> 2 myDatesArray[9]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 9
